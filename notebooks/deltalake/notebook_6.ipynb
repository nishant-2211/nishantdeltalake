# %%
# %sql
DESCRIBE DETAIL deltalakenishant.default.first_table

# %%
# %sql
DESCRIBE EXTENDED deltalakenishant.default.first_table

# %% [markdown]
# # data versioning

# %%
# %sql
DESCRIBE HISTORY delta.`/Volumes/deltalakenishant/default/deltavol/dmlsink/`

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakenishant/default/deltavol/dmlsink/`

# %%
# %sql
RESTORE delta.`/Volumes/deltalakenishant/default/deltavol/dmlsink/`
TO VERSION AS OF 3

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakenishant/default/deltavol/dmlsink/`

# %%
# %sql
SHOW TBLPROPERTIES deltalakenishant.default.first_table

# %%
# %sql
SHOW TBLPROPERTIES delta.`/Volumes/deltalakenishant/default/deltavol/dmlsink/`

# %% [markdown]
# # ## CLONING

# %%
# %sql
CREATE TABLE deltalakenishant.default.clone_table
CLONE delta.`/Volumes/deltalakenishant/default/deltavol/dmlsink/` VERSION AS OF 3

# %% [markdown]
# ## DEEP CLONE

# %%
# %sql
SELECT * FROM deltalakenishant.default.clone_table

# %% [markdown]
# ## SHALLOW CLONE

# %%
# %sql
CREATE TABLE deltalakenishant.default.shallow_clone_table
SHALLOW CLONE deltalakenishant.default.first_table

# %%
# %sql
SELECT * FROM deltalakenishant.default.shallow_clone_table
