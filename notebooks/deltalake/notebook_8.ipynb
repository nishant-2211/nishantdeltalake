# %%
# %sql
CREATE TABLE deltalakenishant.default.uniform_table
USING DELTA TBLPROPERTIES(
  'delta.enableIcebergCompatV2' = 'true',
  'dela.universalFormat.enabledFormats' = 'iceberg'
);

# %%
# %sql
CREATE TABLE IF NOT EXISTS deltalakenishant.default.uniform_table (col1 INT, col2 STRING);
VALUES (1, 'a'), (2, 'b'), (3, 'c')
