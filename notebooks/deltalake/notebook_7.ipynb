# %%
# %sql
ALTER TABLE deltalakenishant.default.clone_table
SET TBLPROPERTIES (delta.enableChangeDataFeed = TRUE)

# %%
# %sql
SELECT * FROM deltalakenishant.default.clone_table

# %%
# %sql
INSERT INTO deltalakenishant.default.clone_table
VALUES (10,100,'zz',2)

# %%
# %sql
UPDATE deltalakenishant.default.clone_table
SET name = 'yy' WHERE cus_id = 10

# %%
# %sql
DELETE FROM deltalakenishant.default.clone_table
WHERE cus_id = 3

# %%
# %sql
DESCRIBE HISTORY deltalakenishant.default.clone_table

# %% [markdown]
# ## see changes using changedatafeed

# %%
# %sql
SELECT * FROM table_changes('deltalakenishant.default.clone_table',1)
