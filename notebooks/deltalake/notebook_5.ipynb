# %%
data = [(1,100,'xyz',1),(9,200,'bb',1),(10,300,'cc',1)]
df = spark.createDataFrame(data,['cus_id','income','name','tip'])

display(df)

# %%
df.write.format("delta")\
    .mode("append")\
    .save("/Volumes/deltalakenishant/default/deltavol/schemalevel/")

# %% [markdown]
# ## column renaming

# %%
# %sql

ALTER TABLE delta.`/Volumes/deltalakenishant/default/deltavol/schemalevel/`
SET TBLPROPERTIES (
  'delta.minReaderVersion' = '2',
  'delta.minWriterVersion' = '5',
  'delta.columnMapping.mode' = 'name'
);

ALTER TABLE delta.`/Volumes/deltalakenishant/default/deltavol/schemalevel/`
RENAME COLUMN name to customer_name;

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakenishant/default/deltavol/schemalevel/`
