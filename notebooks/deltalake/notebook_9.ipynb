# %%
df = spark.read.table('deltalakenishant.default.clone_table')

# %%
display(df)

# %%
df.write.format("delta")\
    .mode("append")\
    .save("/Volumes/deltalakenishant/default/deltavol/optimization/")

# %%
# %sql
DESCRIBE HISTORY Delta.`/Volumes/deltalakenishant/default/deltavol/optimization/`

# %%
# %sql
OPTIMIZE delta.`/Volumes/deltalakenishant/default/deltavol/optimization/`

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakenishant/default/deltavol/optimization/`
WHERE cus_id = '1'

# %%
# %sql
OPTIMIZE delta.`/Volumes/deltalakenishant/default/deltavol/optimization/` ZORDER BY (cus_id)

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakenishant/default/deltavol/optimization/`
WHERE cus_id = '1'

# %%
# %sql
ALTER TABLE deltalakenishant.default.clone_table
CLUSTER BY AUTO

# %%
# %sql
SELECT * FROM delta.`/Volumes/deltalakenishant/default/deltavol/optimization/`
WHERE cus_id = '1'
